# %% [markdown]
# # DATA CLEANING

# %%
#Required packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

# %%
# Createing data frame
pd.set_option("display.max_rows", 50)
# Suppress warnings
warnings.filterwarnings('ignore')

# %%
loan = pd.read_csv("./loan/loan.csv")

# %%
# Print head
loan.head()
# Out:
#         id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  1077501    1296599       5000         5000           4975.0   36 months
# 1  1077430    1314167       2500         2500           2500.0   60 months
# 2  1077175    1313524       2400         2400           2400.0   36 months
# 3  1076863    1277178      10000        10000          10000.0   36 months
# 4  1075358    1311748       3000         3000           3000.0   60 months
#
#   int_rate  installment grade sub_grade  ... num_tl_90g_dpd_24m  \
# 0   10.65%       162.87     B        B2  ...                NaN
# 1   15.27%        59.83     C        C4  ...                NaN
# 2   15.96%        84.33     C        C5  ...                NaN
# 3   13.49%       339.31     C        C1  ...                NaN
# 4   12.69%        67.79     B        B5  ...                NaN
#
#   num_tl_op_past_12m pct_tl_nvr_dlq  percent_bc_gt_75 pub_rec_bankruptcies  \
# ...

# %%
loan.shape
# Out:
# (39717, 111)

# %%
# get details of the data
loan.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39717 entries, 0 to 39716
# Columns: 111 entries, id to total_il_high_credit_limit
# dtypes: float64(74), int64(13), object(24)
# memory usage: 33.6+ MB

# %%
# Find null values in dataset and get the percentage of coloumns having missing columns
missing_values_percentage = loan.isnull().sum() / len(loan) * 100
print(missing_values_percentage)
# Out:
# id                              0.000000
# member_id                       0.000000
# loan_amnt                       0.000000
# funded_amnt                     0.000000
# funded_amnt_inv                 0.000000
#                                  ...
# tax_liens                       0.098195
# tot_hi_cred_lim               100.000000
# total_bal_ex_mort             100.000000
# total_bc_limit                100.000000
# total_il_high_credit_limit    100.000000
# Length: 111, dtype: float64

# %%
# Get coloumns with more than 40% of data
columns_with_missing_data = missing_values_percentage[missing_values_percentage > 40].index
columns_with_missing_data
# Out:
# Index(['mths_since_last_delinq', 'mths_since_last_record', 'next_pymnt_d',
#        'mths_since_last_major_derog', 'annual_inc_joint', 'dti_joint',
#        'verification_status_joint', 'tot_coll_amt', 'tot_cur_bal',
#        'open_acc_6m', 'open_il_6m', 'open_il_12m', 'open_il_24m',
#        'mths_since_rcnt_il', 'total_bal_il', 'il_util', 'open_rv_12m',
#        'open_rv_24m', 'max_bal_bc', 'all_util', 'total_rev_hi_lim', 'inq_fi',
#        'total_cu_tl', 'inq_last_12m', 'acc_open_past_24mths', 'avg_cur_bal',
#        'bc_open_to_buy', 'bc_util', 'mo_sin_old_il_acct',
#        'mo_sin_old_rev_tl_op', 'mo_sin_rcnt_rev_tl_op', 'mo_sin_rcnt_tl',
#        'mort_acc', 'mths_since_recent_bc', 'mths_since_recent_bc_dlq',
#        'mths_since_recent_inq', 'mths_since_recent_revol_delinq',
#        'num_accts_ever_120_pd', 'num_actv_bc_tl', 'num_actv_rev_tl',
#        'num_bc_sats', 'num_bc_tl', 'num_il_tl', 'num_op_rev_tl',
# ...

# %%
# Drop the columns with more than 40% of miss_dataing data
loan_data = loan.drop(columns=columns_with_missing_data)

# %%
# Get the shape and find the number of columns after dropping columns 
loan_data.shape
# Out:
# (39717, 54)

# %%
# Checking for the coloumns that still have some missing values
missing_value = loan_data.isnull().sum() / len(loan_data) * 100
find_missing_columns = missing_value[missing_value > 0]
print(find_missing_columns)
# Out:
# emp_title                      6.191303
# emp_length                     2.706650
# desc                          32.585543
# title                          0.027696
# revol_util                     0.125891
# last_pymnt_d                   0.178765
# last_credit_pull_d             0.005036
# collections_12_mths_ex_med     0.140998
# chargeoff_within_12_mths       0.140998
# pub_rec_bankruptcies           1.754916
# tax_liens                      0.098195
# dtype: float64

# %%
# As we have reduce to 54 columns after data cleaning. Now we will again check for the columns with the unique counts in them.
unique_col = loan_data.nunique()
print(unique_col)
# Out:
# id                          39717
# member_id                   39717
# loan_amnt                     885
# funded_amnt                  1041
# funded_amnt_inv              8205
#                             ...
# acc_now_delinq                  1
# chargeoff_within_12_mths        1
# delinq_amnt                     1
# pub_rec_bankruptcies            3
# tax_liens                       1
# Length: 54, dtype: int64

# %%
# As per the above observation we got the columns with single unique value, so they will not affect much in our analysis
#remove the columns with unique count = 1
uni_col = unique_col[unique_col.values == 1]
unique_col_list = uni_col.index.tolist()
loan_data.drop(columns=unique_col_list, inplace=True)

# %%
#Checking the number of the columns left after removing columns having uniques equal to 1.
loan_data.shape
# Out:
# (39717, 45)

# %%
# After observing the data found that few columns will not  help in the analysis with following reasons so droping them
cols_not_required = ["url", "desc", "out_prncp", "out_prncp_inv", "id", "member_id"]
loan_data.drop(columns=cols_not_required, inplace=True)

# %%
# Now again check for the columns let with missinn data
col_with_missing_data = round(100*(loan_data.isnull().sum()/len(loan_data)), 2)
col_with_missing_data[col_with_missing_data != 0]
# Out:
# emp_title               6.19
# emp_length              2.71
# title                   0.03
# revol_util              0.13
# last_pymnt_d            0.18
# last_credit_pull_d      0.01
# pub_rec_bankruptcies    1.75
# dtype: float64

# %%
#get the unique numbers of values in columns with missing data
for col in col_with_missing_data[col_with_missing_data != 0].index.tolist():
    print(f"Numbers of unique counts in {col}: {len(loan_data[col].unique())}")
# Out:
# Numbers of unique counts in emp_title: 28821
# Numbers of unique counts in emp_length: 12
# Numbers of unique counts in title: 19616
# Numbers of unique counts in revol_util: 1090
# Numbers of unique counts in last_pymnt_d: 102
# Numbers of unique counts in last_credit_pull_d: 107
# Numbers of unique counts in pub_rec_bankruptcies: 4

# %%
# get the unique value count in each above columns
for col in col_with_missing_data[col_with_missing_data != 0].index.tolist():
    print(f"Unique value count in each {col}: {loan_data[col].value_counts()}")
# Out:
# Unique value count in each emp_title: emp_title
# US Army                             134
# Bank of America                     109
# IBM                                  66
# AT&T                                 59
# Kaiser Permanente                    56
#                                    ...
# Connection Inspection                 1
# Veolia Transportaton                  1
# Archdiocese of Galveston Houston      1
# Osram Sylvania                        1
# AIR RESOURCES BOARD                   1
# Name: count, Length: 28820, dtype: int64
# Unique value count in each emp_length: emp_length
# 10+ years    8879
# < 1 year     4583
# 2 years      4388
# 3 years      4095
# 4 years      3436
# 5 years      3282
# 1 year       3240
# 6 years      2229
# 7 years      1773
# 8 years      1479
# 9 years      1258
# Name: count, dtype: int64
# Unique value count in each title: title
# Debt Consolidation                        2184
# Debt Consolidation Loan                   1729
# ...

# %%
# As per the above analysis pub_rec_bankruptcies seem to have 0 as more value counts
loan_data = loan_data[~loan_data.pub_rec_bankruptcies.isnull()]

# %%
#Remove rows where the loan_status is current as current means in-porgress
rows_to_drop = loan_data[loan_data['loan_status'] == "Current"].index
loan_data.drop(rows_to_drop, inplace=True)

# %%
#Check for columns still left with missin counts
missing_val_col = round(100*(loan_data.isnull().mean()), 2)
missing_val_col[missing_val_col > 0]
missing_val_col
# Out:
# loan_amnt                  0.00
# funded_amnt                0.00
# funded_amnt_inv            0.00
# term                       0.00
# int_rate                   0.00
# installment                0.00
# grade                      0.00
# sub_grade                  0.00
# emp_title                  6.19
# emp_length                 2.73
# home_ownership             0.00
# annual_inc                 0.00
# verification_status        0.00
# issue_d                    0.00
# loan_status                0.00
# purpose                    0.00
# title                      0.03
# zip_code                   0.00
# addr_state                 0.00
# dti                        0.00
# delinq_2yrs                0.00
# earliest_cr_line           0.00
# inq_last_6mths             0.00
# open_acc                   0.00
# pub_rec                    0.00
# revol_bal                  0.00
# revol_util                 0.13
# total_acc                  0.00
# total_pymnt                0.00
# ...

# %%
# Found "emp_length", "last_pymnt_d", "revol_util", "emp_title", "title" left with some missing values
# Let's work in fixing the missing values for these columns

# emp_length and emp_title have around 6.19 and 2.73% of missing values, these two columns contains brower information of years and job title can't be imputed directly
#so removing the rows with null values

loan_data = loan_data[~loan_data["emp_length"].isnull()]
loan_data = loan_data[~loan_data["emp_title"].isnull()]
loan_data = loan_data[~loan_data["last_pymnt_d"].isnull()]
loan_data = loan_data[~loan_data["revol_util"].isnull()]
loan_data = loan_data[~loan_data["title"].isnull()]

# %%
#Checking shape again 
loan_data.shape
# Out:
# (35367, 39)

# %%
#Checking still the data is missing or not
loan_data.isnull().sum()
# Out:
# loan_amnt                  0
# funded_amnt                0
# funded_amnt_inv            0
# term                       0
# int_rate                   0
# installment                0
# grade                      0
# sub_grade                  0
# emp_title                  0
# emp_length                 0
# home_ownership             0
# annual_inc                 0
# verification_status        0
# issue_d                    0
# loan_status                0
# purpose                    0
# title                      0
# zip_code                   0
# addr_state                 0
# dti                        0
# delinq_2yrs                0
# earliest_cr_line           0
# inq_last_6mths             0
# open_acc                   0
# pub_rec                    0
# revol_bal                  0
# revol_util                 0
# total_acc                  0
# total_pymnt                0
# total_pymnt_inv            0
# total_rec_prncp            0
# total_rec_int              0
# ...

# %%
loan_data.to_csv("cleand_data.csv")

# %% [markdown]
# # Data Preparation

# %%
duplicate_rows = loan_data.duplicated(keep=False)
duplicate_rows
# Out:
# 1        False
# 3        False
# 5        False
# 6        False
# 7        False
#          ...
# 39551    False
# 39562    False
# 39623    False
# 39666    False
# 39680    False
# Length: 35367, dtype: bool

# %%
loan_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 35367 entries, 1 to 39680
# Data columns (total 39 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   loan_amnt                35367 non-null  int64
#  1   funded_amnt              35367 non-null  int64
#  2   funded_amnt_inv          35367 non-null  float64
#  3   term                     35367 non-null  object
#  4   int_rate                 35367 non-null  object
#  5   installment              35367 non-null  float64
#  6   grade                    35367 non-null  object
#  7   sub_grade                35367 non-null  object
#  8   emp_title                35367 non-null  object
#  9   emp_length               35367 non-null  object
#  10  home_ownership           35367 non-null  object
#  11  annual_inc               35367 non-null  float64
#  12  verification_status      35367 non-null  object
#  13  issue_d                  35367 non-null  object
# ...

# %%
#By looking at the data, divided the columns into their category type
date_columns = ["issue_d", "earliest_cr_line", "last_pymnt_d", "last_credit_pull_d"]

categorical = ["grade", "sub_grade", "emp_title", "home_ownership", "verification_status", "loan_status", "purpose", "title", "zip_code", "addr_state"]
numerical = ["loan_amnt", "funded_amnt", "funded_amnt_inv", "term", "int_rate", "installment", "emp_length", "annual_inc", "dti", "delinq_2yrs", "inq_last_6mths", "open_acc", "pub_rec", "revol_bal", "revol_util", "total_acc", "total_pymnt", "total_pymnt_inv", "total_rec_prncp", "total_rec_int", "total_rec_late_fee", "recoveries", "collection_recovery_fee", "last_pymnt_d", "last_pymnt_amnt", "last_credit_pull_d",  "pub_rec_bankruptcies"]

# %%
#Now check for the dtype of the attributes
loan_data[date_columns].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 35367 entries, 1 to 39680
# Data columns (total 4 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   issue_d             35367 non-null  object
#  1   earliest_cr_line    35367 non-null  object
#  2   last_pymnt_d        35367 non-null  object
#  3   last_credit_pull_d  35367 non-null  object
# dtypes: object(4)
# memory usage: 1.3+ MB

# %%
loan_data[categorical].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 35367 entries, 1 to 39680
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   grade                35367 non-null  object
#  1   sub_grade            35367 non-null  object
#  2   emp_title            35367 non-null  object
#  3   home_ownership       35367 non-null  object
#  4   verification_status  35367 non-null  object
#  5   loan_status          35367 non-null  object
#  6   purpose              35367 non-null  object
#  7   title                35367 non-null  object
#  8   zip_code             35367 non-null  object
#  9   addr_state           35367 non-null  object
# dtypes: object(10)
# memory usage: 3.0+ MB

# %%
loan_data[numerical].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 35367 entries, 1 to 39680
# Data columns (total 27 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   loan_amnt                35367 non-null  int64
#  1   funded_amnt              35367 non-null  int64
#  2   funded_amnt_inv          35367 non-null  float64
#  3   term                     35367 non-null  object
#  4   int_rate                 35367 non-null  object
#  5   installment              35367 non-null  float64
#  6   emp_length               35367 non-null  object
#  7   annual_inc               35367 non-null  float64
#  8   dti                      35367 non-null  float64
#  9   delinq_2yrs              35367 non-null  int64
#  10  inq_last_6mths           35367 non-null  int64
#  11  open_acc                 35367 non-null  int64
#  12  pub_rec                  35367 non-null  int64
#  13  revol_bal                35367 non-null  int64
# ...

# %%
for col in date_columns:
    loan_data[col] = pd.to_datetime(loan_data[col], format = '%b-%y')

# %%
loan_data[date_columns].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 35367 entries, 1 to 39680
# Data columns (total 4 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   issue_d             35367 non-null  datetime64[ns]
#  1   earliest_cr_line    35367 non-null  datetime64[ns]
#  2   last_pymnt_d        35367 non-null  datetime64[ns]
#  3   last_credit_pull_d  35367 non-null  datetime64[ns]
# dtypes: datetime64[ns](4)
# memory usage: 1.3 MB

# %%
#changing percentage
per_col = ["int_rate", "revol_util"]
for col in per_col:
    loan_data[col] = loan_data[col].str.strip('%').astype('float')

# %%
loan_data[per_col].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 35367 entries, 1 to 39680
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   int_rate    35367 non-null  float64
#  1   revol_util  35367 non-null  float64
# dtypes: float64(2)
# memory usage: 828.9 KB

# %%
#Manipulating employee length
loan_data.emp_length.value_counts()
# Out:
# emp_length
# 10+ years    8028
# 2 years      4083
# < 1 year     3978
# 3 years      3833
# 4 years      3206
# 5 years      3043
# 1 year       2959
# 6 years      2062
# 7 years      1638
# 8 years      1361
# 9 years      1176
# Name: count, dtype: int64

# %%
emp_len_conversion = { '< 1 year' : 0, '1 year' : 1, '2 years' : 2, '3 years' : 3, '4 years' : 4, '5 years' : 5, '6 years' : 6, '7 years' : 7, '8 years' : 8, '9 years' : 9, '10+ years' : 10 }
loan_data = loan_data.replace({"emp_length": emp_len_conversion })

# %%
loan_data["emp_length"].value_counts()
# Out:
# emp_length
# 10    8028
# 2     4083
# 0     3978
# 3     3833
# 4     3206
# 5     3043
# 1     2959
# 6     2062
# 7     1638
# 8     1361
# 9     1176
# Name: count, dtype: int64

# %%
#Manipulating term data
loan_data["term"] = loan_data["term"].apply(lambda x : x.split()[0])
loan_data["term"].value_counts()
# Out:
# term
# 36    26377
# 60     8990
# Name: count, dtype: int64

# %%
#Manipulating issue date 
loan_data["issue_month"] = loan_data["issue_d"].dt.month
loan_data["issue_year"] = loan_data["issue_d"].dt.year

# %%
loan_data["issue_month"].value_counts()
# Out:
# issue_month
# 12    3820
# 11    3678
# 10    3436
# 9     3276
# 8     3188
# 7     3115
# 6     2977
# 5     2745
# 4     2669
# 3     2395
# 1     2048
# 2     2020
# Name: count, dtype: int64

# %%
loan_data["issue_year"].value_counts()
# Out:
# issue_year
# 2011    19090
# 2010    10795
# 2009     4423
# 2008     1053
# 2007        6
# Name: count, dtype: int64

# %%
loan_data.to_csv("cleaned_loan_data.csv", encoding="utf-8", index=False)

# %%
clean_data = pd.read_csv("cleaned_loan_data.csv")

# %%
clean_data.shape
# Out:
# (35367, 41)

# %% [markdown]
# # Analysis

# %% [markdown]
# ## Univariate Analysis

# %%
for col in numerical:
    sns.histplot(x=loan_data[col])
    plt.show()

# %%
for col in numerical:
    sns.boxplot(x=loan_data[col])
    plt.show()

# %%
for col in categorical:
    sns.countplot(x=loan_data[col])
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/upgrad/pyenv/lib/python3.12/site-packages/IPython/core/formatters.py:343, in BaseFormatter.__call__(self, obj)
#     341     pass
#     342 else:
# --> 343     return printer(obj)
#     344 # Finally look for special method names
#     345 method = get_real_method(obj, self.print_method)
#
# File ~/upgrad/pyenv/lib/python3.12/site-packages/IPython/core/pylabtools.py:170, in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     167     from matplotlib.backend_bases import FigureCanvasBase
#     168     FigureCanvasBase(fig)
# --> 170 fig.canvas.print_figure(bytes_io, **kw)
#     171 data = bytes_io.getvalue()
#     172 if fmt == 'svg':
#
# ...

# %%
for col in categorical:
    sns.histplot(x=loan_data[col])
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/upgrad/pyenv/lib/python3.12/site-packages/IPython/core/formatters.py:343, in BaseFormatter.__call__(self, obj)
#     341     pass
#     342 else:
# --> 343     return printer(obj)
#     344 # Finally look for special method names
#     345 method = get_real_method(obj, self.print_method)
#
# File ~/upgrad/pyenv/lib/python3.12/site-packages/IPython/core/pylabtools.py:170, in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     167     from matplotlib.backend_bases import FigureCanvasBase
#     168     FigureCanvasBase(fig)
# --> 170 fig.canvas.print_figure(bytes_io, **kw)
#     171 data = bytes_io.getvalue()
#     172 if fmt == 'svg':
#
# ...
